# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv(r'HR-Employee-Attrition.csv')
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
## This statement makes a new attribute Attrition01 which has values 0 and 1. It sets the Attrition attribute to 0 for No Attrition and 1 for Yes Attrition

data['Attrition01']=np.where(data['Attrition']=='Yes',1,0)
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  StandardHours StockOptionLevel  TotalWorkingYears  \
# ...

# %%
## Getting the size of the data

data.shape  ## indicates that there are 1470 rows of data, each having 36 columns. Initial dataset had 35 columns, we added the 36th one as Attrition01
# Out:
# (1470, 36)

# %%
## Descriptive Statistics

data.groupby(['Attrition'])['Age','DailyRate','DistanceFromHome','StandardHours'].agg(['mean','std'])
# Out:
#                  Age            DailyRate             DistanceFromHome  \
#                 mean      std        mean         std             mean
# Attrition
# No         37.561233  8.88836  812.504461  403.208379         8.915653
# Yes        33.607595  9.68935  750.362869  401.899519        10.632911
#
#                     StandardHours
#                 std          mean  std
# Attrition
# No         8.012633            80  0.0
# Yes        8.452525            80  0.0

# %%
data.groupby(['Attrition'])['YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager'].agg(['mean','std'])
# Out:
#           YearsAtCompany           YearsInCurrentRole            \
#                     mean       std               mean       std
# Attrition
# No              7.369019  6.096298           4.484185  3.649402
# Yes             5.130802  5.949984           2.902954  3.174827
#
#           YearsSinceLastPromotion           YearsWithCurrManager
#                              mean       std                 mean       std
# Attrition
# No                       2.234388  3.234762             4.367397  3.594116
# Yes                      1.945148  3.153077             2.852321  3.143349
